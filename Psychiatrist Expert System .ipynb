# %%
import time
import sys
def print_typing(text):
    for each_char in text:
        sys.stdout.write(each_char)
        sys.stdout.flush()
        time.sleep(0.01)
def load():
    for i in range(5):
        print(".", end = "", flush=True)
        time.sleep(0.5)   
name = input("\nEnter You Name : ")
print_typing(f"\nAI : Hi {name}, I am Your Psychiatrist ChatBot, How Can I Assist You!")
print()
print_typing("\nAI : Happy or Sad.")
print()
user_input_1 = input("\nAPPU : ")
if user_input_1 == "Sad" or user_input_1 == "SAD" or user_input_1 == "sad":
    load()
    print_typing("\nAI : I'm really sorry to hear that you're feeling sad. It's completely normal to have moments of sadness, lemme know what happened to you.")
    print()
    print_typing("\n1.Misunderstanding between you and your Parents.\n2.Misunderstanding in Relationship.\n3.Misunderstanding in Friendship.\n4.Feeling Not Good Need Some Advice.\n5.Poor in Studies.")
    print()
    user_input_2 = input("\nAPPU : ")
    if user_input_2 == "1":
        load()
        print_typing("\nAI : I'm sorry to hear that there's a misunderstanding between you and your parents. Misunderstandings within families can be challenging, but they are a common part of human relationships. It's essential to work towards resolving these issues in a healthy and constructive way. Here are some steps you can consider taking to address the misunderstanding:\n1. **Open Communication** : Try to have an open and honest conversation with your parents. Express your feelings and concerns calmly and respectfully. Encourage them to share their perspectives as well.\n2. **Active Listening**: Make an effort to actively listen to what your parents have to say. Understanding their point of view can be the first step towards resolving the misunderstanding.\n3. **Seek Understanding**: Ask questions to clarify the issues and seek a better understanding of each other's feelings and intentions.\n4. **Empathy**: Try to put yourself in their shoes and see the situation from their perspective. This can help build empathy and bridge gaps in understanding.\n5. **Compromise**: Be willing to compromise when appropriate. Sometimes, finding middle ground is necessary to resolve differences.\n6. **Set Boundaries**: Establish healthy boundaries to prevent future misunderstandings. Clearly communicate your needs and expectations and encourage them to do the same.\n7. **Seek Mediation**: If the misunderstanding is too complex or if emotions run high, consider involving a neutral third party, such as a family counselor or therapist, to mediate the conversation.\n8. **Patience**: Remember that resolving misunderstandings can take time. Be patient and persistent in your efforts to rebuild a positive relationship with your parents.\nIt's also important to take care of your emotional well-being during this process. If you find it challenging to handle the situation on your own, consider seeking support from a trusted friend, family member, or a mental health professional who can provide guidance and advice. Remember, it's natural to have disagreements with loved ones, and working through them can lead to stronger, healthier relationships in the long run.")
        print()
    elif user_input_2 == "2":
        load()
        print_typing("\nAI : I'm really sorry to hear that you're going through a tough time due to a misunderstanding in your relationship. Misunderstandings can be difficult and emotional, but they are a common part of human interactions. Here are some steps you can consider to address the situation and work towards resolving the misunderstanding:\n1. **Communication**: Open, honest, and respectful communication is key. Talk to the person involved, express your feelings, and encourage them to share their thoughts as well. \n2. **Active Listening**: Make an effort to actively listen to their perspective. Understanding where they're coming from is essential.\n3. **Empathy**: Try to see things from their point of view and express empathy. This can help bridge gaps in understanding.\n4. **Clarification**: Ask questions to clarify any issues or points of confusion.\n5. **Avoid Blame**: Avoid blaming each other. Focus on understanding and finding a solution rather than assigning blame.\n6. **Seek Resolution**: Work together to find a solution or compromise that addresses the issue at hand.\n7. **Time and Patience**: Resolving misunderstandings may take time. Be patient and persistent in your efforts.\n8. **Consider Mediation**: If you find it challenging to have a productive conversation, you might consider involving a neutral third party, such as a therapist or counselor, to help mediate the discussion.\nRemember, misunderstandings can happen in any relationship. What's important is how you both work together to resolve them. It's also okay to seek support from friends or a therapist if you're finding it particularly challenging to handle on your own. You don't have to go through this alone, and there is help and support available to you.")
        print()
    elif user_input_2 == "3":
        load()
        print_typing("\nAI : I'm really sorry to hear that you're feeling sad due to a misunderstanding with your friends. Misunderstandings among friends can be tough, but they're a common part of any relationship. Here are some steps you can take to address the situation and work towards resolving the misunderstanding:\n1. **Communication**: Reach out to your friends and express your feelings openly and honestly. Encourage them to share their thoughts and feelings as well. Good communication is the foundation of any healthy friendship.\n2. **Active Listening**: Make an effort to actively listen to their perspective. Understanding their point of view is essential for resolving the misunderstanding.\n3. **Empathy**: Try to put yourself in their shoes and understand their feelings and perspective. Empathy can help bridge gaps in understanding.\n4. **Clarification**: Ask questions to clarify any issues or points of confusion. Make sure you have a clear understanding of what caused the misunderstanding.\n5. **Apologize if Necessary**: If you realize that you made a mistake or contributed to the misunderstanding, don't hesitate to apologize. Sincere apologies can go a long way in resolving conflicts.\n6. **Seek Resolution**: Work together with your friends to find a solution or compromise that addresses the issue at hand. It's important to focus on finding common ground and moving forward positively.\n7. **Time and Patience**: Resolving misunderstandings can take time, and it may not happen overnight. Be patient and persistent in your efforts to rebuild your friendship.\n8. **Consider Mediation**: If you find it difficult to have a productive conversation, you might consider involving a neutral third party, such as another trusted friend, to help mediate the discussion.\nRemember that misunderstandings are a natural part of any relationship, and how you work through them can ultimately strengthen your friendship. If you're finding it particularly challenging to handle on your own, don't hesitate to seek support from other friends or a counselor. You don't have to navigate this situation alone, and there is help and support available to you.")
        print()
    elif user_input_2 == "4":
        load()
        print_typing("\nAI : I'm sorry to hear that you're not feeling good. It's completely normal to have moments of sadness or uncertainty. Here are some general pieces of advice that might help:\n1. **Talk to Someone**: Reach out to a friend, family member, or someone you trust to talk about what's bothering you. Sharing your feelings can be very therapeutic.\n2. **Self-Care**: Take care of yourself. Make sure you're getting enough rest, eating well, and engaging in activities that you enjoy.\n3. **Exercise**: Physical activity can have a positive impact on your mood. Consider going for a walk, run, or doing some other form of exercise.\n4. **Mindfulness and Relaxation**: Practice mindfulness or relaxation techniques, such as deep breathing or meditation. These can help reduce stress and anxiety.\n5. **Set Realistic Goals**: Sometimes, setting small, achievable goals can help you feel a sense of accomplishment and improve your mood.\n6. **Limit Exposure to Stressors**: If possible, try to limit your exposure to stressful situations or triggers that are making you feel not good.\n7. **Seek Professional Help**: If your feelings persist or worsen, consider speaking with a mental health professional. They can provide guidance and support tailored to your specific needs.\n8. **Stay Positive**: Try to focus on the positive aspects of your life and practice gratitude. Writing in a gratitude journal can be a helpful exercise.\n9. **Engage in Hobbies**: Doing things you're passionate about or hobbies you enjoy can be a great way to boost your mood.\n10. **Avoid Self-Criticism**: Be kind to yourself. Remember that it's okay to have difficult moments, and self-compassion is essential.\nIf you're comfortable sharing more about what's bothering you or if you have specific questions or concerns, please feel free to let me know, and I'll do my best to provide more targeted advice and support. And remember, it's okay to seek professional help if you need it. Your well-being is important, and there are people who can assist you during difficult times.")
        print()
    elif user_input_2 == "5":
        load()
        print_typing("\nAI : I'm sorry to hear that you're feeling sad about your academic performance. Feeling overwhelmed or underachieving in your studies can be challenging, but there are steps you can take to improve and overcome these difficulties. Here are some tips:\n1. **Self-Reflection**: Take some time to reflect on why you might be struggling with your studies. Are there specific subjects or areas that are particularly challenging for you? Identifying the root causes can help you address them.\n2. **Set Realistic Goals**: Set achievable academic goals. Break them down into smaller, manageable tasks, and celebrate your progress along the way.\n3. **Study Techniques**: Explore different study techniques and find the ones that work best for you. Some people benefit from flashcards, others from summarizing notes, and some from group study sessions.\n4. **Time Management**: Develop a study schedule and manage your time effectively. Allocating specific time slots for studying and avoiding procrastination can make a significant difference.\n5. **Seek Help**: Don't hesitate to ask for help from teachers, tutors, or classmates when you encounter difficulties in a particular subject. They can provide valuable insights and support.\n6. **Healthy Lifestyle**: A balanced diet, regular exercise, and adequate sleep can improve your cognitive abilities and overall well-being, which can positively impact your studies.\n7. **Stay Positive**: Maintain a positive mindset. Believe in your ability to improve and remember that setbacks are a normal part of the learning process.\n8. **Use Available Resources**: Take advantage of educational resources, such as textbooks, online courses, and educational apps. Many free resources are available to help you with your studies.\n9. **Consult a Counselor or Tutor**: If you continue to struggle and feel overwhelmed, consider speaking with a school counselor or a private tutor for additional guidance and support.\n10. **Don't Compare Yourself**: Avoid comparing yourself to others. Everyone has their own pace of learning, and it's important to focus on your own progress and improvement.\nRemember that academic performance is just one aspect of your life, and it doesn't define your worth. Your well-being and happiness are equally important. If you're finding it difficult to manage your emotions or if these feelings persist, consider talking to a mental health professional who can provide support and guidance tailored to your specific needs. You can overcome academic challenges with effort, patience, and the right support.")
        print()
    else:
        load()
        print_typing("\nAI : I think your problem quite complex that even I cannot guess please find some mentor.")
        print()
elif user_input_1 == "HAPPY" or user_input_1 == "happy" or user_input_1 == "Happy":
    load()
    print_typing("\nAI : I'm delighted to hear that you're feeling happy! It's wonderful to experience moments of joy and contentment. If there's anything specific that's contributing to your happiness or if you'd like to share your happiness with me, feel free to do so. Whether you want to talk about your day, share good news, or have any questions or topics you'd like to discuss, I'm here to chat and share in your positive emotions.")
    print()
else:
    load()
    print_typing("\nAI : Please Provide a Correct Information.")
    print()
# Out:
# Enter You Name : appu
#
# AI : Hi appu, I am Your Psychiatrist ChatBot, How Can I Assist You!
#
# AI : Happy or Sad.
#
# APPU : sad
# .....
# AI : I'm really sorry to hear that you're feeling sad. It's completely normal to have moments of sadness, lemme know what happened to you.
#
# 1.Misunderstanding between you and your Parents.
# 2.Misunderstanding in Relationship.
# 3.Misunderstanding in Friendship.
# 4.Feeling Not Good Need Some Advice.
# 5.Poor in Studies.
#
# APPU : 5
# .....
# AI : I'm sorry to hear that you're feeling sad about your academic performance. Feeling overwhelmed or underachieving in your studies can be challenging, but there are steps you can take to improve and overcome these difficulties. Here are some tips:
# 1. **Self-Reflection**: Take some time to reflect on why you might be struggling with your studies. Are there specific subjects or areas that are particularly challenging for you? Identifying the root causes can help you address them.
# ...
