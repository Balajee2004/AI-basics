# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
poppy = cv2.imread("C:/Users/MR.H.BALAJEE/Downloads/Dalmatian puppy.jpg")
plt.imshow(poppy),plt.title("Dalmatian Puppy")
plt.show()
