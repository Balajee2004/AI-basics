# %% [markdown]
# # Question

# %% [markdown]
# Our dear friend mark who lives in california plays soccer in a club named spinoff. Since he is new to california and he loves pets, he bought a cat. Mark is a student who studies in california state University(CSU).

# %% [markdown]
# # Statements

# %% [markdown]
# 1.Mark is a student in California State University(CSU).
# 2.Mark has a cat.
# 3.Mark lives in california.
# 4.Mark plays Soccer.
# 5.Mark is a part of spin off.
# 6.Spin off is a sports club.
# 7.Cat is an pet.
# 8.Mark loves pet.

# %% [markdown]
# # 1. Importing Libraries.

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mr.h.balajee\.conda\envs\aiml1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # 2.Creating a Directed Graph.

# %%
graph_mark = nx.DiGraph(info = "Mark's Details")

# %% [markdown]
# # 3.Creating Nodes along with Positions.

# %%
graph_mark.add_node("Mark", pos = (0,0))
graph_mark.add_node("Cat", pos = (-2,6))
graph_mark.add_node("Student", pos = (2,-5))
graph_mark.add_node("Pet", pos = (1,6))
graph_mark.add_node("California", pos = (4,6))
graph_mark.add_node("Spin off", pos = (-5,-5))
graph_mark.add_node("Soccer", pos = (-5,2))
graph_mark.add_node("Sports Club", pos = (0,-8))
graph_mark.add_node("CSU", pos = (5,-1))
pos = nx.get_node_attributes(graph_mark,"pos")

# %% [markdown]
# # 4.Creating Edges with weights (Relationships).

# %%
graph_mark.add_edge("Mark","Cat",weight = "has a")
graph_mark.add_edge("Mark","Student",weight = "is a")
graph_mark.add_edge("Cat","Pet",weight = "is a")
graph_mark.add_edge("Mark","Soccer",weight = "plays")
graph_mark.add_edge("Mark","Spin off",weight = "is a part")
graph_mark.add_edge("Mark","California",weight = "lives in")
graph_mark.add_edge("Mark","Pet",weight = "loves")
graph_mark.add_edge("Student","CSU",weight = "in")
graph_mark.add_edge("Spin off","Sports Club",weight = "is a")
graph_mark.add_edge("CSU","California",weight = "is in")
weight = nx.get_edge_attributes(graph_mark,"weight")

# %% [markdown]
# # 5.Plot the Graph.

# %%
plt.figure()
nx.draw_networkx(graph_mark, pos, font_weight = "bold" ,node_size = 2000, font_size = 7)
nx.draw_networkx_edge_labels(graph_mark, pos, edge_labels = weight)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {('Mark', 'Cat'): Text(-1.0, 3.0, 'has a'),
#  ('Mark', 'Student'): Text(1.0, -2.5, 'is a'),
#  ('Mark', 'Soccer'): Text(-2.5, 1.0, 'plays'),
#  ('Mark', 'Spin off'): Text(-2.5, -2.5, 'is a part'),
#  ('Mark', 'California'): Text(2.0, 3.0, 'lives in'),
#  ('Mark', 'Pet'): Text(0.5, 3.0, 'loves'),
#  ('Cat', 'Pet'): Text(-0.5, 6.0, 'is a'),
#  ('Student', 'CSU'): Text(3.5, -3.0, 'in'),
#  ('Spin off', 'Sports Club'): Text(-2.5, -6.5, 'is a'),
#  ('CSU', 'California'): Text(4.5, 2.5, 'is in')}
